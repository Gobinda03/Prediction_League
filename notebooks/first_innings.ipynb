# %% [markdown]
# ## First Innings

# %%
import pandas as pd
import joblib

# %%
delivery = pd.read_csv('..\data\processed\deliveries_new.csv')
matches = pd.read_csv('..\data\processed\matches_new.csv')

# %%
delivery['over'] = delivery['over'] + 1

# %%
delivery= delivery[delivery['inning']==1]

# %%
delivery = delivery.sort_values(['match_id', 'over', 'ball'])

# %%
delivery['current_score'] = (
    delivery.groupby('match_id')['total_runs'].cumsum()
)

# %%
delivery['legal_ball'] = delivery['extra_runs'] == 0

delivery['balls_bowled'] = (
    delivery[delivery['legal_ball']]
    .groupby('match_id')
    .cumcount() + 1
)

delivery['balls_bowled'] = delivery.groupby('match_id')['balls_bowled'].ffill()

# %%
delivery['ball_left'] = 120- delivery['balls_bowled']

# %%
delivery = delivery[delivery['ball_left'] > 0]

# %%
delivery['is_wicket'] = (
    delivery['player_dismissed'].notna()
).astype(int)

delivery['total_wicket'] = (
    delivery.groupby('match_id')['is_wicket'].cumsum()
)

# %%
delivery['current_rr'] = (
    delivery['current_score']*6 /
    delivery['balls_bowled'].replace(0,1)
)

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'current_score', 'legal_ball',
#        'balls_bowled', 'ball_left', 'total_wicket', 'current_rr'],
#       dtype='object')

# %%
final_score = delivery.groupby('match_id')['current_score'].max()

# %%
delivery = delivery.merge(
    final_score.rename('final_score'),
    on='match_id'
)

# %%
X = delivery[['current_score','total_wicket','ball_left','current_rr']]
y = delivery['final_score']

# %%
from sklearn.ensemble import RandomForestRegressor
first_innings= RandomForestRegressor(
    n_estimators=300,
    max_depth=12,
    random_state=42,
    n_jobs=-1
)
first_innings.fit(X , y)

joblib.dump(first_innings, '../models/first_innings.pkl')
joblib.dump(X.columns.tolist(), "../models/first_features.pkl")
# Out:
# ['../models/first_features.pkl']

# %%
delivery['predicted_score'] = first_innings.predict(X)

# %%
delivery
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batter  \
# 0         335982       1          KKR          RCB     1     2  BB McCullum
# 1         335982       1          KKR          RCB     1     3  BB McCullum
# 2         335982       1          KKR          RCB     1     4  BB McCullum
# 3         335982       1          KKR          RCB     1     5  BB McCullum
# 4         335982       1          KKR          RCB     1     6  BB McCullum
# ...          ...     ...          ...          ...   ...   ...          ...
# 134809   1426312       1          SRH          KKR    18     5   JD Unadkat
# 134810   1426312       1          SRH          KKR    18     6      B Kumar
# 134811   1426312       1          SRH          KKR    19     1   PJ Cummins
# 134812   1426312       1          SRH          KKR    19     2   PJ Cummins
# 134813   1426312       1          SRH          KKR    19     3   PJ Cummins
#
#             bowler non_striker  batsman_runs  ...  dismissal_kind   fielder  \
# 0          P Kumar  SC Ganguly             0  ...             NaN       NaN
# 1          P Kumar  SC Ganguly             0  ...             NaN       NaN
# 2          P Kumar  SC Ganguly             0  ...             NaN       NaN
# 3          P Kumar  SC Ganguly             0  ...             NaN       NaN
# 4          P Kumar  SC Ganguly             0  ...             NaN       NaN
# ...            ...         ...           ...  ...             ...       ...
# 134809   SP Narine  PJ Cummins             0  ...             lbw       NaN
# 134810   SP Narine  PJ Cummins             0  ...             NaN       NaN
# 134811  AD Russell     B Kumar             0  ...             NaN       NaN
# 134812  AD Russell     B Kumar             0  ...             NaN       NaN
# 134813  AD Russell     B Kumar             0  ...          caught  MA Starc
#
#        current_score  legal_ball balls_bowled ball_left total_wicket  \
# 0                  1        True          1.0     119.0            0
# 1                  2       False          1.0     119.0            0
# 2                  2        True          2.0     118.0            0
# 3                  2        True          3.0     117.0            0
# 4                  2        True          4.0     116.0            0
# ...              ...         ...          ...       ...          ...
# 134809           113        True        104.0      16.0            9
# 134810           113        True        105.0      15.0            9
# 134811           113        True        106.0      14.0            9
# 134812           113        True        107.0      13.0            9
# 134813           113        True        108.0      12.0           10
#
#         current_rr  final_score  predicted_score
# 0         6.000000          222       163.351590
# 1        12.000000          222       168.328123
# 2         6.000000          222       163.440218
# 3         4.000000          222       164.494350
# 4         3.000000          222       162.130444
# ...            ...          ...              ...
# 134809    6.519231          113       122.715650
# 134810    6.457143          113       122.981151
# 134811    6.396226          113       121.953924
# 134812    6.336449          113       119.748429
# 134813    6.277778          113       117.636801
#
# [134814 rows x 25 columns]

# %%
delivery = delivery.merge(
    matches[['id','winner']],
    left_on='match_id',
    right_on='id'
)

# %%
delivery['batting_team_won'] = (delivery['batting_team'] == delivery['winner']).astype(int)

# %%
final_delivery = delivery.drop_duplicates('match_id')

# %%
win_prob_table = (final_delivery.groupby('final_score')['batting_team_won'].mean())

# %%
delivery['win_probability'] = (
    delivery['predicted_score']
    .round()
    .map(win_prob_table)
    .fillna(method='ffill')
    .fillna(0.5)
)
# Out:
# C:\Users\hazra\AppData\Local\Temp\ipykernel_8284\249993399.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   delivery['predicted_score']

# %%
delivery['win_probability'] = (
    delivery.groupby('match_id')['win_probability']
       .ffill()
)

# %%
delivery
# Out:
#        match_id  inning batting_team bowling_team  over  ball      batter  \
# 0        829705       1           MI          KKR     1     1   RG Sharma
# 1        829705       1           MI          KKR     1     2   RG Sharma
# 2        829705       1           MI          KKR     1     3    AJ Finch
# 3        829705       1           MI          KKR     1     4   RG Sharma
# 4        829705       1           MI          KKR     1     5    AJ Finch
# ...         ...     ...          ...          ...   ...   ...         ...
# 71791   1426312       1          SRH          KKR    18     5  JD Unadkat
# 71792   1426312       1          SRH          KKR    18     6     B Kumar
# 71793   1426312       1          SRH          KKR    19     1  PJ Cummins
# 71794   1426312       1          SRH          KKR    19     2  PJ Cummins
# 71795   1426312       1          SRH          KKR    19     3  PJ Cummins
#
#            bowler non_striker  batsman_runs  ...  balls_bowled  ball_left  \
# 0        UT Yadav    AJ Finch             0  ...           1.0      119.0
# 1        UT Yadav    AJ Finch             1  ...           2.0      118.0
# 2        UT Yadav   RG Sharma             1  ...           3.0      117.0
# 3        UT Yadav    AJ Finch             1  ...           4.0      116.0
# 4        UT Yadav   RG Sharma             0  ...           4.0      116.0
# ...           ...         ...           ...  ...           ...        ...
# 71791   SP Narine  PJ Cummins             0  ...         104.0       16.0
# 71792   SP Narine  PJ Cummins             0  ...         105.0       15.0
# 71793  AD Russell     B Kumar             0  ...         106.0       14.0
# 71794  AD Russell     B Kumar             0  ...         107.0       13.0
# 71795  AD Russell     B Kumar             0  ...         108.0       12.0
#
#       total_wicket  current_rr final_score predicted_score       id  winner  \
# 0                0    0.000000         168      165.356031   829705     KKR
# 1                0    3.000000         168      163.118241   829705     KKR
# 2                0    4.000000         168      164.494350   829705     KKR
# 3                0    4.500000         168      164.679702   829705     KKR
# 4                0    6.000000         168      164.949308   829705     KKR
# ...            ...         ...         ...             ...      ...     ...
# 71791            9    6.519231         113      122.715650  1426312     KKR
# 71792            9    6.457143         113      122.981151  1426312     KKR
# 71793            9    6.396226         113      121.953924  1426312     KKR
# 71794            9    6.336449         113      119.748429  1426312     KKR
# 71795           10    6.277778         113      117.636801  1426312     KKR
#
#        batting_team_won  win_probability
# 0                     0         0.300000
# 1                     0         0.666667
# 2                     0         0.600000
# 3                     0         0.300000
# 4                     0         0.300000
# ...                 ...              ...
# 71791                 0         0.000000
# 71792                 0         0.000000
# 71793                 0         1.000000
# 71794                 0         0.000000
# 71795                 0         0.333333
#
# [71796 rows x 29 columns]

# %%
live_match= delivery[delivery['match_id']== 1]
live_match[['current_score','total_wicket','ball_left','current_rr']]
# Out:
# Empty DataFrame
# Columns: [current_score, total_wicket, ball_left, current_rr]
# Index: []

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'current_score', 'legal_ball',
#        'balls_bowled', 'ball_left', 'total_wicket', 'current_rr',
#        'final_score', 'predicted_score', 'id', 'winner', 'batting_team_won',
#        'win_probability'],
#       dtype='object')

# %%
live_match[['balls_bowled','current_score','predicted_score','win_probability','current_rr']]
# Out:
# Empty DataFrame
# Columns: [balls_bowled, current_score, predicted_score, win_probability, current_rr]
# Index: []

# %%
live_match = delivery[delivery['match_id'] == 1426312]
live_match.head
# Out:
# <bound method NDFrame.head of        match_id  inning batting_team bowling_team  over  ball  \
# 71679   1426312       1          SRH          KKR     1     1
# 71680   1426312       1          SRH          KKR     1     2
# 71681   1426312       1          SRH          KKR     1     3
# 71682   1426312       1          SRH          KKR     1     4
# 71683   1426312       1          SRH          KKR     1     5
# ...         ...     ...          ...          ...   ...   ...
# 71791   1426312       1          SRH          KKR    18     5
# 71792   1426312       1          SRH          KKR    18     6
# 71793   1426312       1          SRH          KKR    19     1
# 71794   1426312       1          SRH          KKR    19     2
# 71795   1426312       1          SRH          KKR    19     3
#
#                 batter      bowler non_striker  batsman_runs  ...  \
# 71679  Abhishek Sharma    MA Starc     TM Head             0  ...
# 71680  Abhishek Sharma    MA Starc     TM Head             0  ...
# 71681  Abhishek Sharma    MA Starc     TM Head             0  ...
# 71682  Abhishek Sharma    MA Starc     TM Head             2  ...
# 71683  Abhishek Sharma    MA Starc     TM Head             0  ...
# ...                ...         ...         ...           ...  ...
# 71791       JD Unadkat   SP Narine  PJ Cummins             0  ...
# 71792          B Kumar   SP Narine  PJ Cummins             0  ...
# 71793       PJ Cummins  AD Russell     B Kumar             0  ...
# 71794       PJ Cummins  AD Russell     B Kumar             0  ...
# 71795       PJ Cummins  AD Russell     B Kumar             0  ...
#
#        balls_bowled  ball_left total_wicket  current_rr final_score  \
# 71679           1.0      119.0            0    0.000000         113
# 71680           2.0      118.0            0    0.000000         113
# 71681           3.0      117.0            0    0.000000         113
# 71682           4.0      116.0            0    3.000000         113
# 71683           5.0      115.0            1    2.400000         113
# ...             ...        ...          ...         ...         ...
# 71791         104.0       16.0            9    6.519231         113
# 71792         105.0       15.0            9    6.457143         113
# 71793         106.0       14.0            9    6.396226         113
# 71794         107.0       13.0            9    6.336449         113
# 71795         108.0       12.0           10    6.277778         113
#
#       predicted_score       id  winner  batting_team_won  win_probability
# 71679      165.356031  1426312     KKR                 0         0.300000
# 71680      164.282330  1426312     KKR                 0         0.600000
# 71681      162.344346  1426312     KKR                 0         0.384615
# 71682      162.130444  1426312     KKR                 0         0.384615
# 71683      157.270136  1426312     KKR                 0         0.500000
# ...               ...      ...     ...               ...              ...
# 71791      122.715650  1426312     KKR                 0         0.000000
# 71792      122.981151  1426312     KKR                 0         0.000000
# 71793      121.953924  1426312     KKR                 0         1.000000
# 71794      119.748429  1426312     KKR                 0         0.000000
# 71795      117.636801  1426312     KKR                 0         0.333333
#
# [117 rows x 29 columns]>

# %%
import matplotlib.pyplot as plt
live_match = live_match.sort_values('balls_bowled')

plt.figure(figsize=(10,5))
plt.plot(live_match['balls_bowled'],
         live_match['win_probability'])

plt.xlabel('Balls Bowled')
plt.ylabel('Win Probability')
plt.title('First Innings Win Probability Curve')
plt.show()
